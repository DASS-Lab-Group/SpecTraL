# %%
# check log file for loss convergence with every iteration 

grep "Iteration 0\|Iteration 2900" table3_lora_fair_mi3k.log | head -40

grep "Iteration 0\|Iteration 4900" table3_lora_fair_cosine1_mi5k.log | head -100
grep "Iteration 0\|Iteration 4900" table3_lora_fair_cosine_mi5k.log | head -100
