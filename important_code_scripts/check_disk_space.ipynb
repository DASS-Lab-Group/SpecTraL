# %%
import os
os.getcwd()
# Out:
# '/data/LoRA-FAIR/important_code_scripts'

# %%
# Disk space
# !df -h /projects/bewi/hramesh/SpecTraL/important_code_scripts

# Directory size
# !du -sh /projects/bewi/hramesh/SpecTraL/important_code_scripts
# !du -h --max-depth=1 /projects/bewi/hramesh/SpecTraL/important_code_scripts | sort -hr
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/md127       19T  537G   19T   3% /data
# 16K	/data/LoRA-FAIR/important_code_scripts
# 16K	/data/LoRA-FAIR/important_code_scripts
# 8.0K	/data/LoRA-FAIR/important_code_scripts/.ipynb_checkpoints
