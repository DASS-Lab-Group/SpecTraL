# %%
# below are terminal commands
# kill a job forcefully

kill -9 1037168 # (job id) kills immediately

# check gpu usage

nvidia-smi
# compact and updates every 2 seconds
watch -n 2 'nvidia-smi --query-gpu=utilization.gpu,memory.used,temperature.gpu --format=csv'


# check all the running processes

ps aux | grep python

# check a specific process

ps aux | grep "python main.py" | grep -v grep

# monitor a time and usage of a specific process 

watch -n 2 "ps aux | grep 989025"

# force kill python processes with a specific associated file

pkill -9 -f "python main.py"

# just get the active processes
nvidia-smi pmon -c 1

# look up a process using PID
ps -p <3750202> -o pid,cmd --no-headers
# Out:
#   Cell In[2], line 4
#     kill -9 1037168 # kills immediately
#             ^
# SyntaxError: invalid syntax
