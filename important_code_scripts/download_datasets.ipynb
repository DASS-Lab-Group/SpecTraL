# %%
import os
os.getcwd()
# Out:
# '/data/LoRA-FAIR/important_code_scripts'

# %%
# Navigate to dataset directory

# Run this code in terminal, change the dropbox link to updated link by visiting the NICO++ website


cd /data/tanishk_lora_fair/datasets # wherever you want the dataset to be
mkdir -p NICO++
cd NICO++

# Download NICO++ DG_Benchmark (3.92 GB)

# updated link below :

# "https://www.dropbox.com/scl/fo/ix8u21atdwrstmgjkz2rx/AP5fheclFPjfbBMbeHoqPow?rlkey=kcbecly7tetqu57v4tsmo095m&e=1&dl=0"
    
wget -O NICO_DG_Benchmark.zip "https://www.dropbox.com/scl/fo/ix8u21atdwrstmgjkz2rx/ADq0id6yiyH8aICh_3AR9MI/DG_Benchmark/NICO_DG_Benchmark.zip?rlkey=kcbecly7tetqu57v4tsmo095m&dl=0"

# Download annotations (482 KB)
wget -O NICO_DG_Benchmark_annotation.zip "https://www.dropbox.com/scl/fo/ix8u21atdwrstmgjkz2rx/AIOlzY7yrz5H9mkelcX9e9k/DG_Benchmark/NICO_DG_Benchmark_annotation.zip?rlkey=kcbecly7tetqu57v4tsmo095m&dl=0"

# Extract
unzip NICO_DG_Benchmark.zip
unzip NICO_DG_Benchmark_annotation.zip

# Clean up
rm *.zip

# Verify structure
ls -lh
```

Expected structure after extraction:
```
NICO++/
├── autumn/
├── dim/
├── grass/
├── outdoor/
├── rock/
├── water/
└── env_train_test_split.csv
# Out:
#   Cell In[2], line 32
#     ├── autumn/
#     ^
# SyntaxError: invalid character '├' (U+251C)
