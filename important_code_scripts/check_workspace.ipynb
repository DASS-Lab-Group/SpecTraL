# %%
# Current workspace
# !pwd
# !echo "Current directory: $(pwd)"

# All Brev workspaces (common locations)
# !echo "Checking common workspace locations:"
# !ls -la /data/
# !ls -la /workspace/ 2>/dev/null
# !ls -la /home/nvidia/
# Out:
# /data/LoRA-FAIR/important_code_scripts
# Current directory: /data/LoRA-FAIR/important_code_scripts
# Checking common workspace locations:
# total 16
# drwxrwxrwx  7 root   root    132 Feb 14 23:28 .
# drwxr-xr-x 22 root   root   4096 Oct 23 21:33 ..
# drwx------  4 nvidia nvidia   43 Oct 28 04:20 .Trash-1001
# drwxr-xr-x 12 nvidia nvidia 4096 Feb 16 06:01 FLoRIST_ViT
# drwxr-xr-x 10 nvidia nvidia 4096 Feb 17 20:53 LoRA-FAIR
# drwxr-xr-x 26 nvidia nvidia 4096 Feb 10 23:54 nvidia-FLoRIST
# drwxr-xr-x  5 nvidia nvidia  111 Feb 15 00:23 tanishk_lora_fair
# total 387240
# drwxr-xr-x 20 nvidia nvidia      4096 Feb 14 23:34 .
# drwxr-xr-x  4 root   root        4096 Oct 22 19:04 ..
# -rw-r--r--  1 nvidia nvidia      6148 Nov 24 06:34 .DS_Store
# drwxrwxr-x  2 nvidia nvidia      4096 Oct 22 19:28 .ansible_async
# -rw-------  1 nvidia nvidia     12035 Feb 17 09:03 .bash_history
# -rw-r--r--  1 nvidia nvidia       220 Jan  6  2022 .bash_logout
# ...
